# %%
from collections import deque
import numpy as np
import random as rnd
import tensorflow as tf
import cv2
import cytomatrix
import cytomagic

# %%
cytomagic.run()
# Out:
# TIMESTEP 1 / EPSILON 0.9999981 / ACTION 4 / REWARD 0 / Q_MAX 0.000000e+00
# TIMESTEP 2 / EPSILON 0.9999962 / ACTION 4 / REWARD 0 / Q_MAX 0.000000e+00
# TIMESTEP 3 / EPSILON 0.9999943 / ACTION 1 / REWARD 0 / Q_MAX 0.000000e+00
# TIMESTEP 4 / EPSILON 0.9999924 / ACTION 1 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 5 / EPSILON 0.9999905 / ACTION 4 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 6 / EPSILON 0.9999886 / ACTION 0 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 7 / EPSILON 0.9999867 / ACTION 3 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 8 / EPSILON 0.9999848 / ACTION 3 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 9 / EPSILON 0.9999829 / ACTION 3 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 10 / EPSILON 0.999981 / ACTION 2 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 11 / EPSILON 0.9999791 / ACTION 4 / REWARD 15 / Q_MAX 0.000000e+00
# TIMESTEP 12 / EPSILON 0.9999772 / ACTION 4 / REWARD 15 / Q_MAX 0.000000e+00
# ...
